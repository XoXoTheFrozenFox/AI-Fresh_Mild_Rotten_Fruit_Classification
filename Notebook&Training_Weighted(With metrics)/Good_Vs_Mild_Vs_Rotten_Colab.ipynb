# %% [markdown]
# # Get data from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Imports

# %%
import torch
from torchvision import datasets, transforms, utils
import torch.nn as nn
import torch.optim as optim
import os
import numpy as np
import matplotlib.pyplot as plt
import torch.nn.functional as F

# %% [markdown]
# # Check CUDA Availability

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Dataset Paths

# %%
#Don't forget to rename
fruit_train = '/content/drive/My Drive/notebook_data_and_output/dataset3/train'
fruit_test = '/content/drive/My Drive/notebook_data_and_output/dataset3/test'
data_dir = '/content/drive/My Drive/notebook_data_and_output/dataset3'
print(torch.cuda.device_count())
# Out:
# 1

# %% [markdown]
# # Data Transformations

# %%
data_transform = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.409], [0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.409], [0.229, 0.224, 0.225])
    ])
}

# %% [markdown]
# # Load datasets

# %%
# Load datasets
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transform[x]) for x in ['train', 'test']}

# %% [markdown]
# # Define class names

# %%
class_names = image_datasets['train'].classes
print(class_names)
# Out:
# ['Banana Good', 'Banana Rotten', 'Banana mild', 'Cucumber Good', 'Cucumber Mild', 'Cucumber Rotten', 'Grape Good', 'Grape Mild', 'Grape Rotten', 'Kaki Good', 'Kaki Mild', 'Kaki Rotten', 'Papaya Good', 'Papaya Mild', 'Papaya Rotten', 'Peach Good', 'Peach Mild', 'Peach Rotten', 'Pear Good', 'Pear Mild', 'Pear Rotten', 'Pepper Good', 'Pepper Mild', 'Pepper Rotten', 'Strawberry Mild', 'Strawberry Rotten', 'Tomato Good', 'Tomato Mild', 'Tomato Rotten', 'Watermelon Good', 'Watermelon Mild', 'Watermelon Rotten']

# %% [markdown]
# # Create Data Loaders

# %%
data_loader = {x: torch.utils.data.DataLoader(image_datasets[x], shuffle=True, batch_size=32, num_workers=0) for x in ['train', 'test']}

# %% [markdown]
# # Display sample images

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

inputs, classes = next(iter(data_loader['train']))
out = utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# # Define Neural Network Architecture

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(64)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(128)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.bn3 = nn.BatchNorm2d(256)
        self.conv4 = nn.Conv2d(256, 512, kernel_size=3, padding=1)
        self.bn4 = nn.BatchNorm2d(512)
        self.dropout = nn.Dropout(0.5)
        self.fc1 = nn.Linear(512 * 14 * 14, 512)
        self.fc2 = nn.Linear(512, 32)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.dropout(F.max_pool2d(self.relu(self.bn1(self.conv1(x))), 2))
        x = self.dropout(F.max_pool2d(self.relu(self.bn2(self.conv2(x))), 2))
        x = self.dropout(F.max_pool2d(self.relu(self.bn3(self.conv3(x))), 2))
        x = self.dropout(F.max_pool2d(self.relu(self.bn4(self.conv4(x))), 2))
        x = torch.flatten(x, 1)
        x = self.dropout(self.relu(self.fc1(x)))
        x = self.fc2(x)
        return x

net = Net().to(device)  # Move the model to GPU

# %% [markdown]
# # Load model if it is available

# %%
model_path = '/content/drive/My Drive/notebook_data_and_output/model3/fruit_classifier.pth'
if os.path.exists(model_path):
    net.load_state_dict(torch.load(model_path))
    print("Loaded saved model.")

# %% [markdown]
# # Training

# %%
import torch
import torch.optim as optim
import torch.nn as nn
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os


EPOCHS = 150
patience = 10  # Early stopping patience
i = 0

# Initialize optimizer and learning rate scheduler
optimizer = optim.Adam(net.parameters(), lr=0.001)
cross_el = nn.CrossEntropyLoss()
scheduler = ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.1)

best_loss = float('inf')
no_improvement_epochs = 0

# List to store loss values for plotting
loss_values = []

# File paths
paths = {
    "loss": "/content/drive/My Drive/notebook_data_and_output/metrics/Lossperepoch.txt",
    "accuracy": "/content/drive/My Drive/notebook_data_and_output/metrics/Accuracyperepoch.txt",
    "precision": "/content/drive/My Drive/notebook_data_and_output/metrics/Precisionperepoch.txt",
    "recall": "/content/drive/My Drive/notebook_data_and_output/metrics/Recallperepoch.txt",
    "f1": "/content/drive/My Drive/notebook_data_and_output/metrics/F1Scoreperepoch.txt",
    "roc_auc": "/content/drive/My Drive/notebook_data_and_output/metrics/ROCAUCperepoch.txt",
    "labels": "/content/drive/My Drive/notebook_data_and_output/metrics/Labels.txt",
    "preds": "/content/drive/My Drive/notebook_data_and_output/metrics/Preds.txt",
    "probs": "/content/drive/My Drive/notebook_data_and_output/metrics/Probs.txt"
}

# Training loop
for epoch in range(EPOCHS):
    print(f"Epoch: {epoch + 1}")
    net.train()  # Set the model to training mode
    running_loss = 0.0  # Initialize running loss for the epoch

    for batch_idx, data in enumerate(data_loader['train']):
        x, y = data[0].to(device), data[1].to(device)  # Move data to GPU
        optimizer.zero_grad()  # Clear gradients from the previous step
        output = net(x)  # Forward pass
        loss = cross_el(output, y)  # Compute loss
        loss.backward()  # Backpropagation
        optimizer.step()  # Update model parameters

        running_loss += loss.item()  # Accumulate loss
        i += 1  # Increment step counter

        # Print loss every 100 batches (for example)
        if (batch_idx + 1) % 100 == 0:
            print(f"Batch {batch_idx + 1}/{len(data_loader['train'])}, Loss: {loss.item()}")

    # Calculate and print average loss for the epoch
    average_loss = running_loss / len(data_loader['train'])
    loss_values.append(average_loss)  # Store loss value
    print(f"Average Loss for Epoch {epoch + 1}: {average_loss}")

    # Evaluation on the test set
    net.eval()  # Set the model to evaluation mode
    all_labels = []
    all_preds = []
    all_probs = []

    with torch.no_grad():  # No need to calculate gradients during evaluation
        for data in data_loader['test']:
            x, y = data[0].to(device), data[1].to(device)  # Move data to GPU
            output = net(x)  # Forward pass

            # Get predictions and probabilities
            _, preds = torch.max(output, 1)
            probs = torch.softmax(output, dim=1)  # Probabilities for all classes

            all_labels.extend(y.cpu().numpy())
            all_preds.extend(preds.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    # Compute metrics
    accuracy = accuracy_score(all_labels, all_preds)
    precision = precision_score(all_labels, all_preds, average='weighted', zero_division=0)
    recall = recall_score(all_labels, all_preds, average='weighted', zero_division=0)
    f1 = f1_score(all_labels, all_preds, average='weighted', zero_division=0)
    roc_auc = roc_auc_score(all_labels, all_probs, multi_class='ovr')

    # Print metrics
    print(f"Accuracy for Epoch {epoch + 1}: {accuracy:.4f}")
    print(f"Precision for Epoch {epoch + 1}: {precision:.4f}")
    print(f"Recall for Epoch {epoch + 1}: {recall:.4f}")
    print(f"F1 Score for Epoch {epoch + 1}: {f1:.4f}")
    print(f"ROC AUC for Epoch {epoch + 1}: {roc_auc:.4f}")

    # Save metrics to files
    with open(paths["loss"], "a") as f:
        f.write(f"{epoch + 1}: {average_loss:.4f}\n")
    with open(paths["accuracy"], "a") as f:
        f.write(f"{epoch + 1}: {accuracy:.4f}\n")
    with open(paths["precision"], "a") as f:
        f.write(f"{epoch + 1}: {precision:.4f}\n")
    with open(paths["recall"], "a") as f:
        f.write(f"{epoch + 1}: {recall:.4f}\n")
    with open(paths["f1"], "a") as f:
        f.write(f"{epoch + 1}: {f1:.4f}\n")
    with open(paths["roc_auc"], "a") as f:
        f.write(f"{epoch + 1}: {roc_auc:.4f}\n")

    def append_formatted_data(file_path, data, epoch, header):
        try:
            file_exists = os.path.isfile(file_path)
            with open(file_path, 'a') as f:
                if not file_exists:
                    f.write(header + '\n')
                # Join data with commas and format it
                data_str = ', '.join(map(str, data))
                f.write(f"Epoch {epoch+1}: [{data_str}]\n")
                # Add a blank row to separate epochs
                f.write('\n')
        except IOError as e:
            print(f"Error writing to file {file_path}: {e}")

    all_labels = np.array(all_labels)
    all_preds = np.array(all_preds)
    all_probs = np.array(all_probs)

    append_formatted_data(paths["labels"], all_labels, epoch, "Labels")
    append_formatted_data(paths["preds"], all_preds, epoch, "Predictions")
    append_formatted_data(paths["probs"], all_probs, epoch, "Probabilities")

    # Check for early stopping
    if average_loss < best_loss:
        best_loss = average_loss
        no_improvement_epochs = 0
        # Save the best model
        torch.save(net.state_dict(), model_path)
        print(f"Best model saved after epoch {epoch + 1}")
    else:
        no_improvement_epochs += 1
        print(f"No improvement for {no_improvement_epochs} epochs")

    # Adjust learning rate based on validation loss
    scheduler.step(average_loss)

    # Stop training if no improvement for several epochs
    if no_improvement_epochs >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch: 1
# Batch 100/293, Loss: 1.8908190727233887
# Batch 200/293, Loss: 1.0036383867263794
# Average Loss for Epoch 1: 4.496490688047311
# Accuracy for Epoch 1: 0.5369
# Precision for Epoch 1: 0.4337
# Recall for Epoch 1: 0.5369
# F1 Score for Epoch 1: 0.4580
# ROC AUC for Epoch 1: 0.9760
# Best model saved after epoch 1
# Epoch: 2
# Batch 100/293, Loss: 1.1883589029312134
# Batch 200/293, Loss: 0.7174500823020935
# Average Loss for Epoch 2: 0.9328498061199644
# Accuracy for Epoch 2: 0.5710
# Precision for Epoch 2: 0.5046
# Recall for Epoch 2: 0.5710
# F1 Score for Epoch 2: 0.5083
# ROC AUC for Epoch 2: 0.9553
# Best model saved after epoch 2
# Epoch: 3
# Batch 100/293, Loss: 0.7496415972709656
# Batch 200/293, Loss: 0.48527878522872925
# Average Loss for Epoch 3: 0.7668296438435239
# Accuracy for Epoch 3: 0.7330
# Precision for Epoch 3: 0.6429
# Recall for Epoch 3: 0.7330
# F1 Score for Epoch 3: 0.6672
# ROC AUC for Epoch 3: 0.9803
# Best model saved after epoch 3
# Epoch: 4
# Batch 100/293, Loss: 0.3636730909347534
# Batch 200/293, Loss: 0.7913025617599487
# Average Loss for Epoch 4: 0.7648440034417976
# Accuracy for Epoch 4: 0.7869
# Precision for Epoch 4: 0.7593
# Recall for Epoch 4: 0.7869
# F1 Score for Epoch 4: 0.7634
# ROC AUC for Epoch 4: 0.9697
# Best model saved after epoch 4
# Epoch: 5
# Batch 100/293, Loss: 0.6151914000511169
# Batch 200/293, Loss: 0.6370872855186462
# Average Loss for Epoch 5: 0.7226033639989209
# Accuracy for Epoch 5: 0.7045
# Precision for Epoch 5: 0.6089
# Recall for Epoch 5: 0.7045
# F1 Score for Epoch 5: 0.6364
# ROC AUC for Epoch 5: 0.9738
# Best model saved after epoch 5
# Epoch: 6
# Batch 100/293, Loss: 0.5167058706283569
# Batch 200/293, Loss: 0.5634804368019104
# Average Loss for Epoch 6: 0.6886607191363292
# Accuracy for Epoch 6: 0.7812
# Precision for Epoch 6: 0.7135
# Recall for Epoch 6: 0.7812
# F1 Score for Epoch 6: 0.7344
# ROC AUC for Epoch 6: 0.9681
# Best model saved after epoch 6
# Epoch: 7
# Batch 100/293, Loss: 0.6066505908966064
# Batch 200/293, Loss: 0.5471531748771667
# Average Loss for Epoch 7: 0.6873717717953509
# Accuracy for Epoch 7: 0.7273
# Precision for Epoch 7: 0.6576
# Recall for Epoch 7: 0.7273
# F1 Score for Epoch 7: 0.6746
# ROC AUC for Epoch 7: 0.9668
# Best model saved after epoch 7
# Epoch: 8
# Batch 100/293, Loss: 0.6272971034049988
# Batch 200/293, Loss: 0.43877294659614563
# Average Loss for Epoch 8: 0.6130884257192905
# Accuracy for Epoch 8: 0.7812
# Precision for Epoch 8: 0.7031
# Recall for Epoch 8: 0.7812
# F1 Score for Epoch 8: 0.7292
# ROC AUC for Epoch 8: 0.9718
# Best model saved after epoch 8
# Epoch: 9
# Batch 100/293, Loss: 0.4368278980255127
# Batch 200/293, Loss: 0.7861190438270569
# Average Loss for Epoch 9: 0.5761117747517576
# Accuracy for Epoch 9: 0.8125
# Precision for Epoch 9: 0.7780
# Recall for Epoch 9: 0.8125
# F1 Score for Epoch 9: 0.7762
# ROC AUC for Epoch 9: 0.9745
# Best model saved after epoch 9
# Epoch: 10
# Batch 100/293, Loss: 0.6693941950798035
# Batch 200/293, Loss: 1.0051555633544922
# Average Loss for Epoch 10: 0.5878691960622019
# Accuracy for Epoch 10: 0.7869
# Precision for Epoch 10: 0.7311
# Recall for Epoch 10: 0.7869
# F1 Score for Epoch 10: 0.7382
# ROC AUC for Epoch 10: 0.9775
# No improvement for 1 epochs
# Epoch: 11
# Batch 100/293, Loss: 0.3949911594390869
# Batch 200/293, Loss: 0.7749677896499634
# Average Loss for Epoch 11: 0.5317295482032535
# Accuracy for Epoch 11: 0.7642
# Precision for Epoch 11: 0.7332
# Recall for Epoch 11: 0.7642
# F1 Score for Epoch 11: 0.7191
# ROC AUC for Epoch 11: 0.9892
# Best model saved after epoch 11
# Epoch: 12
# Batch 100/293, Loss: 0.2859552204608917
# Batch 200/293, Loss: 0.4139567017555237
# Average Loss for Epoch 12: 0.5165773160730206
# Accuracy for Epoch 12: 0.8580
# Precision for Epoch 12: 0.8582
# Recall for Epoch 12: 0.8580
# F1 Score for Epoch 12: 0.8403
# ROC AUC for Epoch 12: 0.9765
# Best model saved after epoch 12
# Epoch: 13
# Batch 100/293, Loss: 0.6185861229896545
# Batch 200/293, Loss: 0.751691997051239
# Average Loss for Epoch 13: 0.49587023639638267
# Accuracy for Epoch 13: 0.8011
# Precision for Epoch 13: 0.7562
# Recall for Epoch 13: 0.8011
# F1 Score for Epoch 13: 0.7530
# ROC AUC for Epoch 13: 0.9723
# Best model saved after epoch 13
# Epoch: 14
# Batch 100/293, Loss: 0.5089263916015625
# Batch 200/293, Loss: 0.423850417137146
# Average Loss for Epoch 14: 0.5074104472562518
# Accuracy for Epoch 14: 0.8580
# Precision for Epoch 14: 0.8296
# Recall for Epoch 14: 0.8580
# F1 Score for Epoch 14: 0.8369
# ROC AUC for Epoch 14: 0.9724
# No improvement for 1 epochs
# Epoch: 15
# Batch 100/293, Loss: 0.6419100165367126
# Batch 200/293, Loss: 0.4996732175350189
# Average Loss for Epoch 15: 0.483948974835181
# Accuracy for Epoch 15: 0.8040
# Precision for Epoch 15: 0.8074
# Recall for Epoch 15: 0.8040
# F1 Score for Epoch 15: 0.7937
# ROC AUC for Epoch 15: 0.9721
# Best model saved after epoch 15
# Epoch: 16
# Batch 100/293, Loss: 0.3154006004333496
# Batch 200/293, Loss: 0.4003865420818329
# Average Loss for Epoch 16: 0.4802440285377535
# Accuracy for Epoch 16: 0.8352
# Precision for Epoch 16: 0.7895
# Recall for Epoch 16: 0.8352
# F1 Score for Epoch 16: 0.8036
# ROC AUC for Epoch 16: 0.9735
# Best model saved after epoch 16
# Epoch: 17
# Batch 100/293, Loss: 0.4458487629890442
# Batch 200/293, Loss: 0.46504420042037964
# Average Loss for Epoch 17: 0.4415207321758767
# Accuracy for Epoch 17: 0.8409
# Precision for Epoch 17: 0.7943
# Recall for Epoch 17: 0.8409
# F1 Score for Epoch 17: 0.8097
# ROC AUC for Epoch 17: 0.9776
# Best model saved after epoch 17
# Epoch: 18
# Batch 100/293, Loss: 0.5129653811454773
# Batch 200/293, Loss: 0.37275320291519165
# Average Loss for Epoch 18: 0.42502955726185754
# Accuracy for Epoch 18: 0.8438
# Precision for Epoch 18: 0.7969
# Recall for Epoch 18: 0.8438
# F1 Score for Epoch 18: 0.8125
# ROC AUC for Epoch 18: 0.9730
# Best model saved after epoch 18
# Epoch: 19
# Batch 100/293, Loss: 0.3139772415161133
# Batch 200/293, Loss: 0.3386170268058777
# Average Loss for Epoch 19: 0.39853704865678585
# Accuracy for Epoch 19: 0.8324
# Precision for Epoch 19: 0.7885
# Recall for Epoch 19: 0.8324
# F1 Score for Epoch 19: 0.8007
# ROC AUC for Epoch 19: 0.9809
# Best model saved after epoch 19
# Epoch: 20
# Batch 100/293, Loss: 0.3955855369567871
# Batch 200/293, Loss: 0.4831354320049286
# Average Loss for Epoch 20: 0.38142799128342814
# Accuracy for Epoch 20: 0.8494
# Precision for Epoch 20: 0.8297
# Recall for Epoch 20: 0.8494
# F1 Score for Epoch 20: 0.8235
# ROC AUC for Epoch 20: 0.9775
# Best model saved after epoch 20
# Epoch: 21
# Batch 100/293, Loss: 0.31005364656448364
# Batch 200/293, Loss: 0.15808343887329102
# Average Loss for Epoch 21: 0.3460398307737637
# Accuracy for Epoch 21: 0.8722
# Precision for Epoch 21: 0.8411
# Recall for Epoch 21: 0.8722
# F1 Score for Epoch 21: 0.8513
# ROC AUC for Epoch 21: 0.9907
# Best model saved after epoch 21
# Epoch: 22
# Batch 100/293, Loss: 0.11090084910392761
# Batch 200/293, Loss: 0.10348550975322723
# Average Loss for Epoch 22: 0.3276409567826437
# Accuracy for Epoch 22: 0.8409
# Precision for Epoch 22: 0.7943
# Recall for Epoch 22: 0.8409
# F1 Score for Epoch 22: 0.8097
# ROC AUC for Epoch 22: 0.9820
# Best model saved after epoch 22
# Epoch: 23
# Batch 100/293, Loss: 0.07688168436288834
# Batch 200/293, Loss: 0.32439985871315
# Average Loss for Epoch 23: 0.29897911946444994
# Accuracy for Epoch 23: 0.8580
# Precision for Epoch 23: 0.8634
# Recall for Epoch 23: 0.8580
# F1 Score for Epoch 23: 0.8389
# ROC AUC for Epoch 23: 0.9852
# Best model saved after epoch 23
# Epoch: 24
# Batch 100/293, Loss: 0.34976258873939514
# Batch 200/293, Loss: 0.23643691837787628
# Average Loss for Epoch 24: 0.29355610279627015
# Accuracy for Epoch 24: 0.9006
# Precision for Epoch 24: 0.9128
# Recall for Epoch 24: 0.9006
# F1 Score for Epoch 24: 0.8978
# ROC AUC for Epoch 24: 0.9843
# Best model saved after epoch 24
# Epoch: 25
# Batch 100/293, Loss: 0.200394868850708
# Batch 200/293, Loss: 0.337070494890213
# Average Loss for Epoch 25: 0.28657700685282006
# Accuracy for Epoch 25: 0.9119
# Precision for Epoch 25: 0.9234
# Recall for Epoch 25: 0.9119
# F1 Score for Epoch 25: 0.9068
# ROC AUC for Epoch 25: 0.9890
# Best model saved after epoch 25
# Epoch: 26
# Batch 100/293, Loss: 0.46297410130500793
# Batch 200/293, Loss: 0.17540107667446136
# Average Loss for Epoch 26: 0.2789292888582363
# Accuracy for Epoch 26: 0.8807
# Precision for Epoch 26: 0.8766
# Recall for Epoch 26: 0.8807
# F1 Score for Epoch 26: 0.8651
# ROC AUC for Epoch 26: 0.9856
# Best model saved after epoch 26
# Epoch: 27
# Batch 100/293, Loss: 0.1851624697446823
# Batch 200/293, Loss: 0.4120071828365326
# Average Loss for Epoch 27: 0.26334007695609696
# Accuracy for Epoch 27: 0.8494
# Precision for Epoch 27: 0.8297
# Recall for Epoch 27: 0.8494
# F1 Score for Epoch 27: 0.8235
# ROC AUC for Epoch 27: 0.9849
# Best model saved after epoch 27
# Epoch: 28
# Batch 100/293, Loss: 0.4417705237865448
# Batch 200/293, Loss: 0.21044611930847168
# Average Loss for Epoch 28: 0.24711330696315037
# Accuracy for Epoch 28: 0.9062
# Precision for Epoch 28: 0.8906
# Recall for Epoch 28: 0.9062
# F1 Score for Epoch 28: 0.8958
# ROC AUC for Epoch 28: 0.9788
# Best model saved after epoch 28
# Epoch: 29
# Batch 100/293, Loss: 0.5458558201789856
# Batch 200/293, Loss: 0.1615997552871704
# Average Loss for Epoch 29: 0.24515538390585995
# Accuracy for Epoch 29: 0.9034
# Precision for Epoch 29: 0.8880
# Recall for Epoch 29: 0.9034
# F1 Score for Epoch 29: 0.8930
# ROC AUC for Epoch 29: 0.9766
# Best model saved after epoch 29
# Epoch: 30
# Batch 100/293, Loss: 0.2183501273393631
# Batch 200/293, Loss: 0.1411602944135666
# Average Loss for Epoch 30: 0.23878309884149926
# Accuracy for Epoch 30: 0.8750
# Precision for Epoch 30: 0.8438
# Recall for Epoch 30: 0.8750
# F1 Score for Epoch 30: 0.8542
# ROC AUC for Epoch 30: 0.9763
# Best model saved after epoch 30
# Epoch: 31
# Batch 100/293, Loss: 0.1600610315799713
# Batch 200/293, Loss: 0.18968582153320312
# Average Loss for Epoch 31: 0.22192622330389383
# Accuracy for Epoch 31: 0.8494
# Precision for Epoch 31: 0.8297
# Recall for Epoch 31: 0.8494
# F1 Score for Epoch 31: 0.8235
# ROC AUC for Epoch 31: 0.9775
# Best model saved after epoch 31
# Epoch: 32
# Batch 100/293, Loss: 0.24553707242012024
# Batch 200/293, Loss: 0.21338236331939697
# Average Loss for Epoch 32: 0.22457660457640632
# Accuracy for Epoch 32: 0.8693
# Precision for Epoch 32: 0.8690
# Recall for Epoch 32: 0.8693
# F1 Score for Epoch 32: 0.8513
# ROC AUC for Epoch 32: 0.9730
# No improvement for 1 epochs
# Epoch: 33
# Batch 100/293, Loss: 0.22057992219924927
# Batch 200/293, Loss: 0.028248179703950882
# Average Loss for Epoch 33: 0.2155888539440167
# Accuracy for Epoch 33: 0.8750
# Precision for Epoch 33: 0.8438
# Recall for Epoch 33: 0.8750
# F1 Score for Epoch 33: 0.8542
# ROC AUC for Epoch 33: 0.9744
# Best model saved after epoch 33
# Epoch: 34
# Batch 100/293, Loss: 0.20984305441379547
# Batch 200/293, Loss: 0.12364013493061066
# Average Loss for Epoch 34: 0.18723788346831827
# Accuracy for Epoch 34: 0.9034
# Precision for Epoch 34: 0.8880
# Recall for Epoch 34: 0.9034
# F1 Score for Epoch 34: 0.8930
# ROC AUC for Epoch 34: 0.9757
# Best model saved after epoch 34
# Epoch: 35
# Batch 100/293, Loss: 0.12305637449026108
# Batch 200/293, Loss: 0.07091639935970306
# Average Loss for Epoch 35: 0.1729311343733819
# Accuracy for Epoch 35: 0.8807
# Precision for Epoch 35: 0.8766
# Recall for Epoch 35: 0.8807
# F1 Score for Epoch 35: 0.8651
# ROC AUC for Epoch 35: 0.9768
# Best model saved after epoch 35
# Epoch: 36
# Batch 100/293, Loss: 0.2807621657848358
# Batch 200/293, Loss: 0.2168070375919342
# Average Loss for Epoch 36: 0.16288954653508395
# Accuracy for Epoch 36: 0.8693
# Precision for Epoch 36: 0.8690
# Recall for Epoch 36: 0.8693
# F1 Score for Epoch 36: 0.8513
# ROC AUC for Epoch 36: 0.9805
# Best model saved after epoch 36
# Epoch: 37
# Batch 100/293, Loss: 0.24408294260501862
# Batch 200/293, Loss: 0.10088146477937698
# Average Loss for Epoch 37: 0.1641716754150183
# Accuracy for Epoch 37: 0.9034
# Precision for Epoch 37: 0.8880
# Recall for Epoch 37: 0.9034
# F1 Score for Epoch 37: 0.8930
# ROC AUC for Epoch 37: 0.9804
# No improvement for 1 epochs
# Epoch: 38
# Batch 100/293, Loss: 0.2122371345758438
# Batch 200/293, Loss: 0.20414327085018158
# Average Loss for Epoch 38: 0.15846745532249187
# Accuracy for Epoch 38: 0.9006
# Precision for Epoch 38: 0.8858
# Recall for Epoch 38: 0.9006
# F1 Score for Epoch 38: 0.8901
# ROC AUC for Epoch 38: 0.9851
# Best model saved after epoch 38
# Epoch: 39
# Batch 100/293, Loss: 0.1501348465681076
# Batch 200/293, Loss: 0.20322518050670624
# Average Loss for Epoch 39: 0.13868059596835886
# Accuracy for Epoch 39: 0.8807
# Precision for Epoch 39: 0.8766
# Recall for Epoch 39: 0.8807
# F1 Score for Epoch 39: 0.8651
# ROC AUC for Epoch 39: 0.9728
# Best model saved after epoch 39
# Epoch: 40
# Batch 100/293, Loss: 0.26344671845436096
# Batch 200/293, Loss: 0.10023456066846848
# Average Loss for Epoch 40: 0.14052759584884827
# Accuracy for Epoch 40: 0.8693
# Precision for Epoch 40: 0.8983
# Recall for Epoch 40: 0.8693
# F1 Score for Epoch 40: 0.8577
# ROC AUC for Epoch 40: 0.9879
# No improvement for 1 epochs
# Epoch: 41
# Batch 100/293, Loss: 0.24529419839382172
# Batch 200/293, Loss: 0.27656683325767517
# Average Loss for Epoch 41: 0.13866535061483634
# Accuracy for Epoch 41: 0.8977
# Precision for Epoch 41: 0.9117
# Recall for Epoch 41: 0.8977
# F1 Score for Epoch 41: 0.8941
# ROC AUC for Epoch 41: 0.9869
# Best model saved after epoch 41
# Epoch: 42
# Batch 100/293, Loss: 0.1472785472869873
# Batch 200/293, Loss: 0.11594202369451523
# Average Loss for Epoch 42: 0.1387689061111721
# Accuracy for Epoch 42: 0.9176
# Precision for Epoch 42: 0.9253
# Recall for Epoch 42: 0.9176
# F1 Score for Epoch 42: 0.9154
# ROC AUC for Epoch 42: 0.9764
# No improvement for 1 epochs
# Epoch: 43
# Batch 100/293, Loss: 0.16589058935642242
# Batch 200/293, Loss: 0.15235157310962677
# Average Loss for Epoch 43: 0.13825310230530868
# Accuracy for Epoch 43: 0.9062
# Precision for Epoch 43: 0.8906
# Recall for Epoch 43: 0.9062
# F1 Score for Epoch 43: 0.8958
# ROC AUC for Epoch 43: 0.9844
# Best model saved after epoch 43
# Epoch: 44
# Batch 100/293, Loss: 0.06850294023752213
# Batch 200/293, Loss: 0.2292746603488922
# Average Loss for Epoch 44: 0.13959373743471978
# Accuracy for Epoch 44: 0.8977
# Precision for Epoch 44: 0.8839
# Recall for Epoch 44: 0.8977
# F1 Score for Epoch 44: 0.8871
# ROC AUC for Epoch 44: 0.9811
# No improvement for 1 epochs
# Epoch: 45
# Batch 100/293, Loss: 0.17725057899951935
# Batch 200/293, Loss: 0.16981303691864014
# Average Loss for Epoch 45: 0.12496211588041371
# Accuracy for Epoch 45: 0.9034
# Precision for Epoch 45: 0.9154
# Recall for Epoch 45: 0.9034
# F1 Score for Epoch 45: 0.9007
# ROC AUC for Epoch 45: 0.9745
# Best model saved after epoch 45
# Epoch: 46
# Batch 100/293, Loss: 0.046558987349271774
# Batch 200/293, Loss: 0.28539830446243286
# Average Loss for Epoch 46: 0.11990791085924525
# Accuracy for Epoch 46: 0.8778
# Precision for Epoch 46: 0.8757
# Recall for Epoch 46: 0.8778
# F1 Score for Epoch 46: 0.8600
# ROC AUC for Epoch 46: 0.9844
# Best model saved after epoch 46
# Epoch: 47
# Batch 100/293, Loss: 0.06648939847946167
# Batch 200/293, Loss: 0.034516897052526474
# Average Loss for Epoch 47: 0.1197055267457534
# Accuracy for Epoch 47: 0.9176
# Precision for Epoch 47: 0.9253
# Recall for Epoch 47: 0.9176
# F1 Score for Epoch 47: 0.9154
# ROC AUC for Epoch 47: 0.9787
# Best model saved after epoch 47
# Epoch: 48
# Batch 100/293, Loss: 0.24062445759773254
# Batch 200/293, Loss: 0.12831616401672363
# Average Loss for Epoch 48: 0.126561850868019
# Accuracy for Epoch 48: 0.9233
# Precision for Epoch 48: 0.9266
# Recall for Epoch 48: 0.9233
# F1 Score for Epoch 48: 0.9229
# ROC AUC for Epoch 48: 0.9831
# No improvement for 1 epochs
# Epoch: 49
# Batch 100/293, Loss: 0.19531254470348358
# Batch 200/293, Loss: 0.2515665888786316
# Average Loss for Epoch 49: 0.11794472786485118
# Accuracy for Epoch 49: 0.8977
# Precision for Epoch 49: 0.8839
# Recall for Epoch 49: 0.8977
# F1 Score for Epoch 49: 0.8871
# ROC AUC for Epoch 49: 0.9775
# Best model saved after epoch 49
# Epoch: 50
# Batch 100/293, Loss: 0.10078555345535278
# Batch 200/293, Loss: 0.049507565796375275
# Average Loss for Epoch 50: 0.11583675196779578
# Accuracy for Epoch 50: 0.9261
# Precision for Epoch 50: 0.9282
# Recall for Epoch 50: 0.9261
# F1 Score for Epoch 50: 0.9260
# ROC AUC for Epoch 50: 0.9821
# Best model saved after epoch 50
# Epoch: 51
# Batch 100/293, Loss: 0.24060213565826416
# Batch 200/293, Loss: 0.055430762469768524
# Average Loss for Epoch 51: 0.09469421906715846
# Accuracy for Epoch 51: 0.8949
# Precision for Epoch 51: 0.9124
# Recall for Epoch 51: 0.8949
# F1 Score for Epoch 51: 0.8884
# ROC AUC for Epoch 51: 0.9813
# Best model saved after epoch 51
# Epoch: 52
# Batch 100/293, Loss: 0.0014374275924637914
# Batch 200/293, Loss: 0.13098300993442535
# Average Loss for Epoch 52: 0.08491949866320811
# Accuracy for Epoch 52: 0.9375
# Precision for Epoch 52: 0.9375
# Recall for Epoch 52: 0.9375
# F1 Score for Epoch 52: 0.9375
# ROC AUC for Epoch 52: 0.9841
# Best model saved after epoch 52
# Epoch: 53
# Batch 100/293, Loss: 0.10026022791862488
# Batch 200/293, Loss: 0.04548070207238197
# Average Loss for Epoch 53: 0.07152067762431046
# Accuracy for Epoch 53: 0.9318
# Precision for Epoch 53: 0.9327
# Recall for Epoch 53: 0.9318
# F1 Score for Epoch 53: 0.9318
# ROC AUC for Epoch 53: 0.9848
# Best model saved after epoch 53
# Epoch: 54
# Batch 100/293, Loss: 0.2257295548915863
# Batch 200/293, Loss: 0.0015684457030147314
# Average Loss for Epoch 102: 0.014479253030371338
# Accuracy for Epoch 102: 0.9375
# Precision for Epoch 102: 0.9375
# Recall for Epoch 102: 0.9375
# F1 Score for Epoch 102: 0.9375
# ROC AUC for Epoch 102: 0.9865
# No improvement for 5 epochs
# Epoch: 103
# Batch 100/293, Loss: 4.809125130122993e-06
# Batch 200/293, Loss: 0.012562001124024391
# Average Loss for Epoch 103: 0.014919266383777639
# Accuracy for Epoch 103: 0.9375
# Precision for Epoch 103: 0.9375
# Recall for Epoch 103: 0.9375
# F1 Score for Epoch 103: 0.9375
# ROC AUC for Epoch 103: 0.9858
# No improvement for 6 epochs
# Epoch: 104
# Batch 100/293, Loss: 2.3995193259906955e-05
# Batch 200/293, Loss: 0.033638905733823776
# Average Loss for Epoch 104: 0.012397041801951586
# Accuracy for Epoch 104: 0.9375
# Precision for Epoch 104: 0.9375
# Recall for Epoch 104: 0.9375
# F1 Score for Epoch 104: 0.9375
# ROC AUC for Epoch 104: 0.9870
# No improvement for 7 epochs
# Epoch: 105
# Batch 100/293, Loss: 3.251512680435553e-05
# Batch 200/293, Loss: 0.006329439580440521
# Average Loss for Epoch 105: 0.012963906422083978
# Accuracy for Epoch 105: 0.9375
# Precision for Epoch 105: 0.9375
# Recall for Epoch 105: 0.9375
# F1 Score for Epoch 105: 0.9375
# ROC AUC for Epoch 105: 0.9875
# No improvement for 8 epochs
# Epoch: 106
# Batch 100/293, Loss: 0.0003137645253445953
# Batch 200/293, Loss: 7.915758942544926e-06
# Average Loss for Epoch 106: 0.014470501199246857
# Accuracy for Epoch 106: 0.9375
# Precision for Epoch 106: 0.9375
# Recall for Epoch 106: 0.9375
# F1 Score for Epoch 106: 0.9375
# ROC AUC for Epoch 106: 0.9858
# No improvement for 9 epochs
# Epoch: 107
# Batch 100/293, Loss: 5.68838368053548e-06
# Batch 200/293, Loss: 0.003954397514462471
# Average Loss for Epoch 107: 0.013578860060051571
# Accuracy for Epoch 107: 0.9375
# Precision for Epoch 107: 0.9375
# Recall for Epoch 107: 0.9375
# F1 Score for Epoch 107: 0.9375
# ROC AUC for Epoch 107: 0.9863
# No improvement for 10 epochs
# Early stopping triggered

# %% [markdown]
# # Graphs

# %%
# Plot ROC curve after training
fpr, tpr, _ = roc_curve(np.array(all_labels), np.array(all_probs)[:, 1], pos_label=1)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.4f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Plot confusion matrix after training
cm = confusion_matrix(all_labels, all_preds)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # Evaluation

# %%
k = 0
j = 0
correct = 0
total = 0
with torch.no_grad():
    for data in data_loader['test']:
        k += 1
        print("Test set: " + str(k))
        x, y = data[0].to(device), data[1].to(device)  # Move data to GPU
        output = net(x)
        for idx, i in enumerate(output):
            j += 1
            #print(j)
            if torch.argmax(i) == y[idx]:
                correct += 1
            total += 1

print(f'Accuracy: {round(correct/total, 3)}')
# Out:
# Test set: 1
# Test set: 2
# Test set: 3
# Test set: 4
# Test set: 5
# Test set: 6
# Test set: 7
# Test set: 8
# Test set: 9
# Test set: 10
# Test set: 11
# Accuracy: 0.938
